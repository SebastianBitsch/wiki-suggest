# %% [markdown]
# Testing playground and plots

# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

sns.set_theme(style="darkgrid")
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %%
path = "/work3/s204163/wiki/data-batches/articles.pickle"

with open(path, "rb") as f:
    articles = pickle.load(f)

print(len(articles))
article_lengths = [len(article.user_ids) for article in articles.values()]
# Remove 
N = len(article_lengths)
percentiles = [80, 85, 90, 95, 96, 97, 98, 99, 100]
top_percentiles = [101 - p for p in percentiles]
repr_percentiles = ([int(N * p / 100) for p in top_percentiles])
article_percentiles = list(map(int, np.percentile(article_lengths, percentiles)))

print("Percentiles:        ", percentiles)
print("Top percentiles:    ", top_percentiles)
print("Repr percentiles:   ", repr_percentiles)
print("Article percentiles:", article_percentiles)

# Boxplot & Log boxplot
df = pd.DataFrame(article_lengths)
fig, ax = plt.subplots(1, 2)
fig.suptitle("User connections per article", fontsize=16)

df.plot(kind='box', ax=ax[0])
ax[0].set_title("Boxplot")
ax[0].set_ylabel("Number of user connections")
ax[0].set_xticklabels([])
df.apply(np.log).plot(kind='box', ax=ax[1])
ax[1].set_title("Logarithmic boxplot")
ax[1].set_ylabel("Number of user connections")
ax[1].set_xticklabels([])
plt.tight_layout()
plt.show()

print(" & ".join([str(p) for p in percentiles])+r"\\")
print(" & ".join([str(p) for p in repr_percentiles])+r"\\")
print(" & ".join([str(p) for p in article_percentiles])+r"\\")
# Out:
# 20050
# Percentiles:         [80, 85, 90, 95, 96, 97, 98, 99, 100]
# Top percentiles:     [21, 16, 11, 6, 5, 4, 3, 2, 1]
# Repr percentiles:    [4210, 3208, 2205, 1203, 1002, 802, 601, 401, 200]
# Article percentiles: [172, 244, 383, 747, 889, 1088, 1443, 2010, 12268]
# 80 & 85 & 90 & 95 & 96 & 97 & 98 & 99 & 100\\
# 4210 & 3208 & 2205 & 1203 & 1002 & 802 & 601 & 401 & 200\\
# 172 & 244 & 383 & 747 & 889 & 1088 & 1443 & 2010 & 12268\\

# %%
df.describe()
# Out:
#              0
# count 20050.00
# mean    162.88
# std     395.99
# min       1.00
# 25%      15.00
# 50%      39.00
# 75%     129.00
# max   12268.00

# %%
path = "/work3/s204163/wiki/data-batches/users.pickle"

with open(path, "rb") as f:
    users = pickle.load(f)

print(len(users))

user_lengths = [len(user.article_ids) for user in users.values()]
# Out:
# 1419020

# %%
N = len(user_lengths)
percentiles = [80, 85, 90, 95, 96, 97, 98, 99, 100]
top_percentiles = [101 - p for p in percentiles]
repr_percentiles = ([int(N * p / 100) for p in top_percentiles])
user_percentiles = list(map(int, np.percentile(user_lengths, percentiles)))

print("Percentiles:        ", percentiles)
print("Top percentiles:    ", top_percentiles)
print("Repr percentiles:   ", repr_percentiles)
print("Article percentiles:", user_percentiles)

# Boxplot & Log boxplot
df = pd.DataFrame(user_lengths)
fig, ax = plt.subplots(1, 2)
fig.suptitle("Article connections per user", fontsize=16)

df.plot(kind='box', ax=ax[0])
ax[0].set_title("Boxplot")
ax[0].set_ylabel("Number of article connections")
ax[0].set_xticklabels([])
df.apply(np.log).plot(kind='box', ax=ax[1])
ax[1].set_title("Logarithmic boxplot")
ax[1].set_ylabel("Number of article connections")
ax[1].set_xticklabels([])
plt.tight_layout()
plt.show()

print(" & ".join([str(p) for p in percentiles])+r"\\")
print(" & ".join([str(p) for p in repr_percentiles])+r"\\")
print(" & ".join([str(p) for p in user_percentiles])+r"\\")
# Out:
# Percentiles:         [80, 85, 90, 95, 96, 97, 98, 99, 100]
# Top percentiles:     [21, 16, 11, 6, 5, 4, 3, 2, 1]
# Repr percentiles:    [297994, 227043, 156092, 85141, 70951, 56760, 42570, 28380, 14190]
# Article percentiles: [1, 2, 2, 5, 6, 7, 11, 20, 10622]
# 80 & 85 & 90 & 95 & 96 & 97 & 98 & 99 & 100\\
# 297994 & 227043 & 156092 & 85141 & 70951 & 56760 & 42570 & 28380 & 14190\\
# 1 & 2 & 2 & 5 & 6 & 7 & 11 & 20 & 10622\\

# %%
df.describe()
# Out:
#                0
# count 1419020.00
# mean        2.30
# std        20.35
# min         1.00
# 25%         1.00
# 50%         1.00
# 75%         1.00
# max     10622.00

# %%
path = "/work3/s204163/wiki/data-batches/articles_keep_cutoff98_sync.pickle"

with open(path, "rb") as f:
    articles = pickle.load(f)

print(len(articles))
article_lengths = [len(article.user_ids) for article in articles.values()]
# Remove 
N = len(article_lengths)
percentiles = [80, 85, 90, 95, 96, 97, 98, 99, 100]
top_percentiles = [101 - p for p in percentiles]
repr_percentiles = ([int(N * p / 100) for p in top_percentiles])
article_percentiles = list(map(int, np.percentile(article_lengths, percentiles)))

print("Percentiles:        ", percentiles)
print("Top percentiles:    ", top_percentiles)
print("Repr percentiles:   ", repr_percentiles)
print("Article percentiles:", article_percentiles)

# Boxplot & Log boxplot
df = pd.DataFrame(article_lengths)
fig, ax = plt.subplots(1, 2)
fig.suptitle("User connections per article [Filtered]", fontsize=16)

df.plot(kind='box', ax=ax[0])
ax[0].set_title("Boxplot")
ax[0].set_ylabel("Number of user connections")
ax[0].set_xticklabels([])
df.apply(np.log).plot(kind='box', ax=ax[1])
ax[1].set_title("Logarithmic boxplot")
ax[1].set_ylabel("Number of user connections")
ax[1].set_xticklabels([])
plt.tight_layout()
plt.show()
# Out:
# 17963
# Percentiles:         [80, 85, 90, 95, 96, 97, 98, 99, 100]
# Top percentiles:     [21, 16, 11, 6, 5, 4, 3, 2, 1]
# Repr percentiles:    [3772, 2874, 1975, 1077, 898, 718, 538, 359, 179]
# Article percentiles: [90, 133, 204, 372, 430, 508, 597, 722, 1193]

# %%
df.describe()
# Out:
#              0
# count 17963.00
# mean     72.14
# std     140.27
# min       1.00
# 25%       5.00
# 50%      16.00
# 75%      66.00
# max    1193.00

# %%
path = "/work3/s204163/wiki/data-batches/users_keep_cutoff98_sync.pickle"

with open(path, "rb") as f:
    users = pickle.load(f)

print(len(users))

user_lengths = [len(user.article_ids) for user in users.values()]
N = len(user_lengths)
percentiles = [80, 85, 90, 95, 96, 97, 98, 99, 100]
top_percentiles = [101 - p for p in percentiles]
repr_percentiles = ([int(N * p / 100) for p in top_percentiles])
user_percentiles = list(map(int, np.percentile(user_lengths, percentiles)))

print("Percentiles:        ", percentiles)
print("Top percentiles:    ", top_percentiles)
print("Repr percentiles:   ", repr_percentiles)
print("Article percentiles:", user_percentiles)

# Boxplot & Log boxplot
df = pd.DataFrame(user_lengths)
fig, ax = plt.subplots(1, 2)
fig.suptitle("Article connections per user [Filtered]", fontsize=16)

df.plot(kind='box', ax=ax[0])
ax[0].set_title("Boxplot")
ax[0].set_ylabel("Number of article connections")
ax[0].set_xticklabels([])
df.apply(np.log).plot(kind='box', ax=ax[1])
ax[1].set_title("Logarithmic boxplot")
ax[1].set_ylabel("Number of article connections")
ax[1].set_xticklabels([])
plt.tight_layout()
plt.show()
# Out:
# 982463
# Percentiles:         [80, 85, 90, 95, 96, 97, 98, 99, 100]
# Top percentiles:     [21, 16, 11, 6, 5, 4, 3, 2, 1]
# Repr percentiles:    [206317, 157194, 108070, 58947, 49123, 39298, 29473, 19649, 9824]
# Article percentiles: [1, 2, 2, 3, 3, 4, 5, 6, 10]

# %%
df.describe()
# Out:
#               0
# count 982463.00
# mean       1.32
# std        0.95
# min        1.00
# 25%        1.00
# 50%        1.00
# 75%        1.00
# max       10.00

# %%
# user_count = 0
# for user in users.keys():
#     if user in articles.keys():
#         user_count += 1
        
# article_count = 0
# for article in articles.keys():
#     if article in users.keys():
#         article_count += 1
        
# print(user_count)
# print(article_count)
